# %% [markdown]
# # Introduction
# This assignment will test how well you're able to perform various data science-related tasks.
#
# Each Problem Group below will center around a particular dataset that you have worked with before.
#
# To ensure you receive full credit for a question, make sure you demonstrate the appropriate pandas, altair, or other commands as requested in the provided code blocks.
#
# You may find that some questions require multiple steps to fully answer. Others require some mental arithmetic in addition to pandas commands. Use your best judgment.
#
# ## Submission
# Each problem group asks a series of questions. This assignment consists of two submissions:
#
# 1. After completing the questions below, open the Module 01 Assessment Quiz in Canvas and enter your answers to these questions there.
#
# 2. After completing and submitting the quiz, save this Colab notebook as a GitHub Gist (You'll need to create a GitHub account for this), by selecting `Save a copy as a GitHub Gist` from the `File` menu above.
#
#     In Canvas, open the Module 01 Assessment GitHub Gist assignment and paste the GitHub Gist URL for this notebook. Then submit that assignment.

# %% [markdown]
# ## Problem Group 1
#
# For the questions in this group, you'll work with the Netflix Movies Dataset found at this url: [https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/netflix_titles.csv](https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/netflix_titles.csv)

# %% [markdown]
# ### Question 1
# Load the dataset into a Pandas data frame and determine what data type is used to store the `release_year` feature.

# %%
import pandas as pd
netflix = pd.read_csv("https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/netflix_titles.csv")
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
netflix.head(20)
# Out:
#      show_id     type                                              title  \
# 0   81145628    Movie            Norm of the North: King Sized Adventure
# 1   80117401    Movie                         Jandino: Whatever it Takes
# 2   70234439  TV Show                                 Transformers Prime
# 3   80058654  TV Show                   Transformers: Robots in Disguise
# 4   80125979    Movie                                       #realityhigh
# 5   80163890  TV Show                                            Apaches
# 6   70304989    Movie                                           Automata
# 7   80164077    Movie                 Fabrizio Copano: Solo pienso en mi
# 8   80117902  TV Show                                       Fire Chasers
# 9   70304990    Movie                                        Good People
# 10  80169755    Movie                        Joaquín Reyes: Una y no más
# 11  70299204    Movie                            Kidnapping Mr. Heineken
# 12  80182480    Movie                           Krish Trish and Baltiboy
# 13  80182483    Movie           Krish Trish and Baltiboy: Battle of Wits
# 14  80182596    Movie     Krish Trish and Baltiboy: Best Friends Forever
# 15  80182482    Movie          Krish Trish and Baltiboy: Comics of India
# 16  80182597    Movie  Krish Trish and Baltiboy: Oversmartness Never ...
# 17  80182481    Movie                  Krish Trish and Baltiboy: Part II
# 18  80182621    Movie       Krish Trish and Baltiboy: The Greatest Trick
# 19  80057969    Movie                                               Love
#
#                            director  \
# 0          Richard Finn, Tim Maltby
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                  Fernando Lebrija
# 5                               NaN
# 6                       Gabe Ibáñez
# 7   Rodrigo Toro, Francisco Schultz
# 8                               NaN
# 9                 Henrik Ruben Genz
# 10            José Miguel Contreras
# 11                 Daniel Alfredson
# 12                              NaN
# 13      Munjal Shroff, Tilak Shetty
# 14      Munjal Shroff, Tilak Shetty
# 15                     Tilak Shetty
# 16                     Tilak Shetty
# 17                              NaN
# 18      Munjal Shroff, Tilak Shetty
# 19                       Gaspar Noé
#
#                                                  cast  \
# 0   Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                    Jandino Asporaat
# 2   Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3   Will Friedle, Darren Criss, Constance Zimmer, ...
# 4   Nesta Cooper, Kate Walsh, John Michael Higgins...
# 5   Alberto Ammann, Eloy Azorín, Verónica Echegui,...
# 6   Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                
# 13  An artisan is cheated of his payment, a lion o...
# 14  A cat, monkey and donkey team up to narrate fo...
# 15  In three comic-strip-style tales, a boy tries ...
# 16  A cat, monkey and donkey learn the consequence...
# 17  Animal minstrels narrate stories about a monke...
# 18  The consequences of trickery are explored in s...
# 19  A man in an unsatisfying marriage recalls the ...

# %% [markdown]
# ### Question 2
# Filter your dataset so it contains only `TV Shows`. How many of those TV Shows were rated `TV-Y7`?

# %%
tvy7_shows = netflix[netflix["rating"] == "TV-Y7"]
tvy7_shows.head(20)
# Out:
#       show_id     type                                              title  \
# 3    80058654  TV Show                   Transformers: Robots in Disguise
# 12   80182480    Movie                           Krish Trish and Baltiboy
# 13   80182483    Movie           Krish Trish and Baltiboy: Battle of Wits
# 15   80182482    Movie          Krish Trish and Baltiboy: Comics of India
# 16   80182597    Movie  Krish Trish and Baltiboy: Oversmartness Never ...
# 17   80182481    Movie                  Krish Trish and Baltiboy: Part II
# 18   80182621    Movie       Krish Trish and Baltiboy: The Greatest Trick
# 34   80221550  TV Show                         Archibald's Next Big Thing
# 64   80239337  TV Show                                             Ben 10
# 70   80116921  TV Show                                      We Bare Bears
# 85   80019931    Movie                   Monster High: Boo York, Boo York
# 149  80115346  TV Show                                              Hilda
# 180  70259208  TV Show                          Transformers: Rescue Bots
# 329  81154956  TV Show                           Transformers: Cyberverse
# 375  80105933  TV Show                   LEGO Elves: Secrets of Elvendale
# 406  80118841    Movie                                         Figaro Pho
# 428  81021976    Movie  The Spooky Tale of Captain Underpants Hack-a-ween
# 442  80215730  TV Show                      Legend Quest: Masters of Myth
# 464  80141858    Movie          LEGO Jurassic World: The Indominus Escape
# 621  80995687    Movie                    Little Singham: Kaal Ki Tabaahi
#
#                         director  \
# 3                            NaN
# 12                           NaN
# 13   Munjal Shroff, Tilak Shetty
# 15                  Tilak Shetty
# 16                  Tilak Shetty
# 17                           NaN
# 18   Munjal Shroff, Tilak Shetty
# 34                           NaN
# 64                           NaN
# 70                           NaN
# 85                   William Lau
# 149                          NaN
# 180                          NaN
# 329                          NaN
# 375                          NaN
# 406              Luke Jurevicius
# 428                          NaN
# 442                          NaN
# 464             Michael D. Black
# 621                Prakash Satam
#
#                                                   cast  \
# 3    Will Friedle, Darren Criss, Constance Zimmer, ...
# 12   Damandeep Singh Baggan, Smita Malhotra, Baba S...
# 13   Damandeep Singh Baggan, Smita Malhotra, Baba S...
# 15   Damandeep Singh Baggan, Smita Malhotra, Baba S...
# 16       Rishi Gambhir, Smita Malhotra, Deepak Chachra
# 17   Damandeep Singh Baggan, Smita Malhotra, Baba S...
# 18   Damandeep Singh Baggan, Smita Malhotra, Baba S...
# 34   Tony Hale, Rosamund Pike, Jordan Fisher, Chels...
# 64   Tara Strong, Montse Hernandez, David Kaye, Rog...
# 70      Eric Edelstein, Demetri Martin, Bobby Moynihan
# 85   Karen Strassman, Celeste Henderson, Wendee Lee...
# 149  Bella Ramsey, Ameerah Falzon-Ojo, Oliver Nelso...
# 180  Lacey Chabert, Elan Garfias, Maurice LaMarche,...
# 329  Sophia Isabella, Jeremy Levy, Jacob Tillman, R...
# 375  Ashleigh Ball, Erin Mathews, Rebecca Husain, K...
# 406                                    Luke Jurevicius
# 428  Nat Faxon, Jay Gragnani, Ramone Hamilton, Sean...
# 442  Johnny Rose, Annemarie Blanco, Paul Tei, Oscar...
tvy7_2000s = tvy7_shows[(tvy7_shows["release_year"] >= 2000) & (tvy7_shows["release_year"] <= 2009)]
tvy7_2000s.head()
# Out:
#        show_id   type                     title  \
# 12    80182480  Movie  Krish Trish and Baltiboy
# 406   80118841  Movie                Figaro Pho
# 2346  70048905  Movie                     Iqbal
# 3514  70081015  Movie        Garfield Gets Real
# 3515  70100448  Movie       Garfield's Fun Fest
#
#                            director  \
# 12                              NaN
# 406                 Luke Jurevicius
# 2346                Nagesh Kukunoor
# 3514  Mark A.Z. Dippé, Kyung Ho Lee
# 3515   Mark A.Z. Dippé, Eondeok Han
#
#                                                    cast  \
# 12    Damandeep Singh Baggan, Smita Malhotra, Baba S...
# 406                                     Luke Jurevicius
# 2346  Shreyas Talpade, Naseeruddin Shah, Girish Karn...
# 3514  Frank Welker, Wally Wingert, Gregg Berger, Jen...
# 3515  Frank Welker, Tim Conway, Gregg Berger, Wally ...
#
#                          country         date_added  release_year rating  \
# 12                           NaN  September 8, 2017          2009  TV-Y7
# 406               United Kingdom  September 1, 2016          2008  TV-Y7
# 2346                       India      March 1, 2018          2006  TV-Y7
# 3514                         NaN    January 1, 2020          2007  TV-Y7
# 3515  United States, South Korea    January 1, 2020          2008  TV-Y7
#
#      duration                                         listed_in  \
# 12     58 min                          Children & Family Movies
# 406    29 min                Children & Family Movies, Comedies
# 2346  127 min  Dramas, Independent Movies, International Movies
# 3514   78 min                Children & Family Movies, Comedies
# 3515   79 min                Children & Family Movies, Comedies
#
#                                             description
# 12    A team of minstrels, including a monkey, cat a...
# 406   Quirky little Figaro has a whole alphabet's wo...
# 2346  A boy with a hearing and speech impairment – a...
# 3514  After trying to live in the "real world" and c...
# 3515  Garfield has long been the champ at a yearly c...

# %% [markdown]
# ## Problem Group 2
#
# For the questions in this group, you'll work with the Cereal Dataset found at this url: [https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/cereal.csv](https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/cereal.csv)

# %% [markdown]
# ### Question 4
# After importing the dataset into a pandas data frame, determine the median amount of `protein` in cereal brands manufactured by Kelloggs. (`mfr` code "K")

# %%
import pandas as pd
cereal = pd.read_csv("https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/cereal.csv")
kelloggs  = cereal[cereal["mfr"] == "K"]
kelloggs["protein"].median()
# Out:
# 3.0

# %%
kelloggs.head(20)
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                   Apple Jacks   K    C       110        2    0     125
# 16                  Corn Flakes   K    C       100        2    0     290
# 17                    Corn Pops   K    C       110        1    0      90
# 19           Cracklin' Oat Bran   K    C       110        3    3     140
# 21                      Crispix   K    C       110        2    0     220
# 24                  Froot Loops   K    C       110        2    1     125
# 25               Frosted Flakes   K    C       110        1    0     200
# 26          Frosted Mini-Wheats   K    C       100        3    0       0
# 28                Fruitful Bran   K    C       120        3    0     240
# 38  Just Right Crunchy  Nuggets   K    C       110        2    1     170
# 39       Just Right Fruit & Nut   K    C       140        3    1     170
# 46         Mueslix Crispy Blend   K    C       160        3    2     150
# 48             Nut&Honey Crunch   K    C       120        2    1     190
# 49    Nutri-Grain Almond-Raisin   K    C       140        3    2     220
# 50            Nutri-grain Wheat   K    C        90        3    0     170
# 53                   Product 19   K    C       100        3    0     320
# 58                  Raisin Bran   K    C       120        3    1     210
# 60               Raisin Squares   K    C        90        2    0       0
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 2     9.0    7.0       5     320        25      3    1.00  0.33  59.425505
# 3    14.0    8.0       0     330        25      3    1.00  0.50  93.704912
# 6     1.0   11.0      14      30        25      2    1.00  1.00  33.174094
# 16    1.0   21.0       2      35        25      1    1.00  1.00  45.863324
# 17    1.0   13.0      12      20        25      2    1.00  1.00  35.782791
# 19    4.0   10.0       7     160        25      3    1.00  0.50  40.448772
# 21    1.0   21.0       3      30        25      3    1.00  1.00  46.895644
# 24    1.0   11.0      13      30        25      2    1.00  1.00  32.207582
# 25    1.0   14.0      11      25        25      1    1.00  0.75  31.435973
# 26    3.0   14.0       7     100        25      2    1.00  0.80  58.345141
# 28    5.0   14.0      12     190        25      3    1.33  0.67  41.015492
# 38    1.0   17.0       6      60       100      3    1.00  1.00  36.523683
# 39    2.0   20.0       9      95       100      3    1.30  0.75  36.471512
# 46    3.0   17.0      13     160        25      3    1.50  0.67  30.313351
# 48    0.0   15.0       9      40        25      2    1.00  0.67  29.924285
# 49    3.0   21.0       7     130        25      3    1.33  0.67  40.692320
# 50    3.0   18.0       2      90        25      3    1.00  1.00  59.642837
# 53    1.0   20.0       3      45       100      3    1.00  1.00  41.503540
# 58    5.0   14.0      12     240        25      2    1.33  0.75  39.259197
# 60    2.0   15.0       6     110        25      3    1.00  0.50  55.333142

# %% [markdown]
# ### Question 5
# In order to comply with new government regulations, all cereals must now come with a "Healthiness" rating. This rating is calculated based on this formula:
#
#     healthiness = (protein + fiber) / sugar
#
# Create a new `healthiness` column populated with values based on the above formula.
#
# Then, determine the median healthiness value for only General Mills cereals (`mfr` = "G"), rounded to two decimal places.

# %%
cereal["healthiness"] = ((cereal["protein"] + cereal["fiber"]) / cereal["sugars"])
median_healthiness = cereal["healthiness"].median()
rounded_median = round(median_healthiness, 2)
print(rounded_median)
# Out:
# 0.67

# %% [markdown]
# ## Problem Group 3
#
# For the questions in this group, you'll work with the Titanic Dataset found at this url: [https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv](https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv)

# %% [markdown]
# ### Question 6
#
# After loading the dataset into a pandas DataFrame, create a new column called `NameGroup` that contains the first letter of the passenger's surname in lower case.
#
# Note that in the dataset, passenger's names are provided in the `Name` column and are listed as:
#
#     Surname, Given names
#
# For example, if a passenger's `Name` is `Braund, Mr. Owen Harris`, the `NameGroup` column should contain the value `b`.
#
# Then count how many passengers have a `NameGroup` value of `k`.

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/titanic.csv")
titanic["NameGroup"] = titanic["Name"].str[0].str.lower()
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       No       3
# 1            2      Yes       1
# 2            3      Yes       3
# 3            4      Yes       1
# 4            5       No       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked NameGroup
# 0      0         A/5 21171   7.2500   NaN        S         b
# 1      0          PC 17599  71.2833   C85        C         c
# 2      0  STON/O2. 3101282   7.9250   NaN        S         h
# 3      0            113803  53.1000  C123        S         f
# 4      0            373450   8.0500   NaN        S         a

# %%
k_passengers = titanic["NameGroup"].value_counts()["k"]
print(k_passengers)
# Out:
# 28
